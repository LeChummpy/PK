# %%
gewicht = [[15],[15],[15],[13],[14],[15],
           [5],[8],[10],[8],[9],[10]]

schulterhöhe = [[20],[35],[28],[23],[30],[35],
                [28],[31],[35],[25],[32],[30]]

x = [[1],[2],[3],[4],[5],[6]]
y = [[15],[30],[36],[39],[49],[65]]

# %%
import matplotlib.pyplot as plt

plt.xlim(0, 7)
plt.ylim(0, 70)
plt.xlabel("Gewicht in kg",fontsize=18)
plt.ylabel("Schulterhöhe in cm",fontsize=18)
plt.grid()
plot = plt.scatter(x, y)
