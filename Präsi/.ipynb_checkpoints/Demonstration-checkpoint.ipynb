# %%
gewicht = [[15],[20],[23],[5],[8],[10]]

schulterhöhe = [[31],[40],[45],[28],[31],[35]]

# %%
import matplotlib.pyplot as plt

plt.xlim(0, 25)
plt.ylim(0, 50)
plot = plt.scatter(gewicht, schulterhöhe)
